# %%
'''
ESERCIZIO1: Individua 3 task di qualsiasi tipo, scrivi un algoritmo in forma testuale, cioè i passi
necessari, per ognuno dei task selezionati.

TASK1: Fare lo shampoo: aprire l'acqua - bagnarsi i capelli - insaponare i capelli - 
                        sciacquare i capelli - tamponare i capelli - asciugare i capelli

TASK2: Preparare una torta: selezionare ingredienti - pesare ingredienti - mescolare ingredienti -
                            imburrare teglia - versare composto nella teglia - impostare temperatura - 
                            riscaldare forno - infornare la teglia - uscire la teglia - tagliare la torta

TASK3: Aggiornare il telefono: scaricare l'aggiornamento - avviare l'aggiornamento - aspettare che l'aggiornamento finisca 
                                riavviare il telefono
'''
# Out:
# "\nESERCIZIO1: Individua 3 task di qualsiasi tipo, scrivi un algoritmo in forma testuale, cioè i passi\nnecessari, per ognuno dei task selezionati.\n\nTASK1: Fare lo shampoo: aprire l'acqua - bagnarsi i capelli - insaponare i capelli - \n                        sciacquare i capelli - tamponare i capelli - asciugare i capelli\n\nTASK2: Preparare una torta: selezionare ingredienti - pesare ingredienti - mescolare ingredienti -\n                            imburrare teglia - versare composto nella teglia - impostare temperatura - \n                            riscaldare forno - infornare la teglia - uscire la teglia - tagliare la torta\n\nTASK3: Aggiornare il telefono: scaricare l'aggiornamento - avviare l'aggiornamento - aspettare che l'aggiornamento finisca \n                                riavviare il telefono\n"

# %%
#ESERCIZIO2: Abbiamo 25 studenti, memorizza il dato in una variabile.

student_number=25

#ESERCIZIO3: Abbiamo 25 studenti, memorizza il dato in una variabile e stampala.
student_number=25
message=f"Il numero di studenti è {student_number}."
print(message)


#ESERCIZIO4: Abbiamo 25 studenti, memorizza il dato in una variabile; abbiamo altri 3 studenti, memorizza il dato in un'altra variabile.

student_number=25
student_second_number=3


#ESERCIZIO5: Abbiamo 25 studenti, memorizza il dato in una variabile;
#            Abbiamo altri 3 studenti, memorizza il dato in un'altra variabile. 
#            Crea un'altra variabile ancora che conterrà la somma delle prime due, poi stampala.

student_number=25
student_second_number=3
total_student= student_number + student_second_number
message2=f"Il numero di studenti totali è {total_student}."
print(message2)

# %%
#ESERCIZIO6: Crea una variabile che contiene la stringa "Epicode", stampala.

str= "Epicode"
print(str)

#ESERCIZIO7: Variabile x = 10, incrementala di 2 e poi moltiplicala per 3.

x=10
x=(10+2)*3
print(x)

#ESERCIZIO8: Crea la seguenti stringhe e verificane la lunghezza con len() 

str1 = "Windows" 
str2 = "Excel" 
str3 = "Powerpoint" 
str4 = "Word"  

print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))

#ESERCIZIO9: Calcola e stampa quanti secondi ci sono in un anno non bisestile
days=365
hour=24
minutes=60
seconds=60

total_seconds=seconds*minutes*hour*days 
print("il numero di secondi totali in un anno non bisestile è: ", total_seconds)


#ESERCIZIO10: Abbiamo la seguente stringa my_string = "I am studying Python" 
#             Trasformala in modo che tutti i caratteri siano maiuscoli 
#             Trasformala in modo che tutti i caratteri siano minuscoli 
#             Sostituire la sottostringa "Python" con la stringa "a lot" 
#             Usare il metodo .strip(); cambia qualcosa? perché? 
#             Usare il metodo .split(); per trovare tutte le parole

my_string = "I am studying Python"

print(my_string.upper())
print(my_string.lower())
print(my_string.replace("Python", "a lot"))
print(my_string.strip())
print(my_string.split())


#ESERCIZIO11: Abbiamo due liste, una di studenti e una di corsi: 
#             studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]  
#             corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"] 
#             Sapendo che Emma segue Data Analyst 
#                         Faith segue Backend 
#                         Grace segue Frontend 
#                         Henry segue Cybersecurity 
#             alla lista cui mancano dei dati, aggiungiamo i dati mancanti uno alla volta con il metodo .append()

students = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"] 
courses = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

courses.append("Frontend")
courses.append("Cybersecurity")

print(students, courses)
# Out:
# Epicode
# 36
# 7
# 5
# 10
# 4
# il numero di secondi totali in un anno non bisestile è:  31536000
# I AM STUDYING PYTHON
# i am studying python
# I am studying a lot
# I am studying Python
# ['I', 'am', 'studying', 'Python']
# ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry'] ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
